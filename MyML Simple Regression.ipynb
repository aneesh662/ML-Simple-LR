# %% [markdown]
# <h1><center> ML Simple Linear Regression </h1>

# %% [markdown]
# <h2>Step 1: Import Necessary Libraries</h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import warnings

# Suppress all warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# <h2>Step 2: Import the Dataset</h2>

# %%
# Load the dataset
data = pd.read_csv(r"Experience Salary.csv")

# Display the dataset
print(data)
# Out:
#    Experience  Salary
# 0           1   30000
# 1           2   35000
# 2           3   40000
# 3           4   45000
# 4           5   50000
# 5           6   55000
# 6           7   60000
# 7           8   65000
# 8           9   70000
# 9          10   75000

# %% [markdown]
# <h2>Step 3: Prepare the Data</h2>

# %%
#Split the dataset into features (X) and target (y), then further split into training and testing sets.
# Define features and target variable
X = data[['Experience']]
y = data['Salary']

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# <h2>Step 4: Train the Model</h2>

# %%
# Create a Linear Regression object
model = LinearRegression()

# Fit the model with the training data
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# <h2>Step 5: Make Predictions>/h2>

# %%
# Predict on the test set
y_pred = model.predict(X_test)

# Predict a specific value
predicted_salary_for_5_years = model.predict([[5]])
predicted_salary_for_12_years = model.predict([[12]])

print(f"Predicted salary for 5 years of experience: {predicted_salary_for_5_years[0]}")
print(f"Predicted salary for 12 years of experience: {predicted_salary_for_12_years[0]}")
# Out:
# Predicted salary for 5 years of experience: 50000.0
# Predicted salary for 12 years of experience: 85000.0

# %% [markdown]
# <h2>Step 6: Evaluate the Model</h2>

# %%
#Check the accuracy, coefficient, and intercept of the model.

# Model accuracy
accuracy = model.score(X_test, y_test)
print(f"Model accuracy: {accuracy}")

# Model coefficients
print(f"Model coefficient (m): {model.coef_[0]}")
print(f"Model intercept (b): {model.intercept_}")

# Calculate and print the Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Model accuracy: 1.0
# Model coefficient (m): 5000.0
# Model intercept (b): 25000.0
# Mean Squared Error: 0.0

# %% [markdown]
# <h2>Step 7: Visualize the Results</h2>

# %%
# Plot the data points and the regression line
plt.scatter(data['Experience'], data['Salary'], color='r', marker='.')
plt.plot(data['Experience'], model.predict(data[['Experience']]), color='blue')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Experience vs Salary')
plt.show()

# %% [raw]
# Explanation
# Import Libraries: Import necessary libraries, including train_test_split for splitting the data and mean_squared_error for evaluating the model.
#
# Prepare the Data: Split the data into training and test sets to evaluate the model's performance.
#
# Train the Model: Fit the Linear Regression model with the training data.
#
# Make Predictions: Predict salaries for specific values and on the test set.
#
# Evaluate the Model: Check accuracy, coefficients, and intercept, and calculate the Mean Squared Error.
#
# Visualize Results: Plot the data points and regression line to visualize the fit.
#
# This implementation ensures that you train your model on a subset of the data and evaluate it on another subset, providing a better understanding of its performance.
